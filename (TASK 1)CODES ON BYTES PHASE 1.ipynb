# %% [markdown]
# # TASK ONE

# %% [markdown]
# # Call this public Api and create a csv dataset using python and pandas
# Api: - https://data.binance.com/api/v3/ticker/24hr

# %%
import requests
import pandas as pd

# %%
response = requests.get("https://api.binance.com/api/v3/ticker/24hr")
data_one = response.json()

# %%
df = pd.DataFrame(data_one)

# %%
df.to_csv("binance_data.csv", index=False)

# %%
df.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00030000             -0.506       0.05888046     0.05927000
# 1   LTCBTC   0.00003900              1.669       0.00234749     0.00233700
# 2   BNBBTC  -0.00000800             -0.104       0.00766263     0.00769500
# 3   NEOBTC  -0.00000020             -0.078       0.00025671     0.00025770
# 4  QTUMETH   0.00001500              1.101       0.00137604     0.00136500
#
#     lastPrice      lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.05896000   0.01320000  0.05895000   33.82560000  0.05896000  ...
# 1  0.00237600   1.86300000  0.00237400  128.16000000  0.00237500  ...
# 2  0.00768700   0.03200000  0.00768700   21.59900000  0.00768800  ...
# 3  0.00025770  20.00000000  0.00025770  710.71000000  0.00025800  ...
# 4  0.00137800   4.90000000  0.00137100  763.20000000  0.00137900  ...
#
#     openPrice   highPrice    lowPrice          volume    quoteVolume  \
# 0  0.05926000  0.05928000  0.05855000  31524.23250000  1856.16139678
# 1  0.00233700  0.00237900  0.00230800  39971.38300000    93.83246224
# 2  0.00769500  0.00770000  0.00758400  25358.01400000   194.30912816
# 3  0.00025790  0.00025870  0.00025270  10370.08000000     2.66213069
# 4  0.00136300  0.00138900  0.00136300    161.40000000     0.22209310
#
#         openTime      closeTime    firstId     lastId  count
# 0  1696487582237  1696573982237  423617004  423650416  33413
# 1  1696487575223  1696573975223   93710350   93719046   8697
# 2  1696487570677  1696573970677  227553771  227575151  21381
# 3  1696487560644  1696573960644   45549339   45550518   1180
# 4  1696487570186  1696573970186    5403508    5403532     25
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#         symbol  priceChange priceChangePercent weightedAvgPrice  \
# 2301   USDTVAI  -0.00300000             -0.297       1.01177766
# 2302  ARBFDUSD   0.01730000              2.027       0.86754121
# 2303  FDUSDTRY   0.08000000              0.288      27.67470337
# 2304  FRONTTRY   0.85900000             10.601       8.73388443
# 2305  SUIFDUSD   0.01210000              2.846       0.43985195
#
#      prevClosePrice    lastPrice        lastQty     bidPrice        bidQty  \
# 2301     1.00400000   1.00600000     4.10000000   1.00600000   95.90000000
# 2302     0.00000000   0.87080000    11.30000000   0.87340000  114.40000000
# 2303     0.00000000  27.83000000  1971.00000000  27.83000000  762.00000000
# 2304     0.00000000   8.96200000   762.00000000   8.94900000  535.00000000
# 2305     0.00000000   0.43730000    33.10000000   0.43680000  228.90000000
#
#          askPrice  ...    openPrice    highPrice     lowPrice  \
# 2301   1.01200000  ...   1.00900000   1.01400000   1.00500000
# 2302   0.87770000  ...   0.85350000   1.10020000   0.84160000
# 2303  27.84000000  ...  27.75000000  35.00000000  26.50000000
# 2304   8.96900000  ...   8.10300000   9.12900000   8.10300000
# 2305   0.43890000  ...   0.42520000   0.50000000   0.34800000
#
#                  volume         quoteVolume       openTime      closeTime  \
# 2301      6789.70000000       6869.66680000  1696469327188  1696555727188
# 2302     39156.70000000      33970.05081000  1696487142902  1696573542902
# 2303   1201800.00000000   33259458.51000000  1696487140949  1696573540949
# 2304  17156504.00000000  149842923.17100000  1696487150339  1696573550339
# 2305     51856.80000000      22809.31443000  1696487092981  1696573492981
#
#       firstId  lastId  count
# 2301      345     364     20
# 2302        0     108    109
# 2303        0    3304   3305
# 2304        0   40763  40764
# 2305        0     199    200
#
# [5 rows x 21 columns]

# %%
print(df)
# Out:
#         symbol  priceChange priceChangePercent weightedAvgPrice  \
# 0       ETHBTC  -0.00030000             -0.506       0.05888046
# 1       LTCBTC   0.00003900              1.669       0.00234749
# 2       BNBBTC  -0.00000800             -0.104       0.00766263
# 3       NEOBTC  -0.00000020             -0.078       0.00025671
# 4      QTUMETH   0.00001500              1.101       0.00137604
# ...        ...          ...                ...              ...
# 2301   USDTVAI  -0.00300000             -0.297       1.01177766
# 2302  ARBFDUSD   0.01730000              2.027       0.86754121
# 2303  FDUSDTRY   0.08000000              0.288      27.67494420
# 2304  FRONTTRY   0.88200000             10.885       8.73487935
# 2305  SUIFDUSD   0.01210000              2.846       0.43985195
#
#      prevClosePrice    lastPrice        lastQty     bidPrice          bidQty  \
# 0        0.05927000   0.05896000     0.01320000   0.05895000     33.82560000
# 1        0.00233700   0.00237600     1.86300000   0.00237400    128.16000000
# 2        0.00769500   0.00768700     0.03200000   0.00768700     21.59900000
# 3        0.00025770   0.00025770    20.00000000   0.00025770    710.71000000
# 4        0.00136500   0.00137800     4.90000000   0.00137100    763.20000000
# ...             ...          ...            ...          ...             ...
# 2301     1.00400000   1.00600000     4.10000000   1.00600000     95.90000000
# 2302     0.00000000   0.87080000    11.30000000   0.87330000    114.50000000
# 2303     0.00000000  27.83000000   602.00000000  27.83000000  30120.00000000
# 2304     0.00000000   8.98500000  2509.00000000   8.98100000   3687.00000000
# 2305     0.00000000   0.43730000    33.10000000   0.43650000    229.00000000
#
#          askPrice  ...    openPrice    highPrice     lowPrice  \
# 0      0.05896000  ...   0.05926000   0.05928000   0.05855000
# 1      0.00237500  ...   0.00233700   0.00237900   0.00230800
# 2      0.00768800  ...   0.00769500   0.00770000   0.00758400
# 3      0.00025800  ...   0.00025790   0.00025870   0.00025270
# 4      0.00137900  ...   0.00136300   0.00138900   0.00136300
# ...           ...  ...          ...          ...          ...
# 2301   1.01200000  ...   1.00900000   1.01400000   1.00500000
# 2302   0.87470000  ...   0.85350000   1.10020000   0.84160000
# 2303  27.84000000  ...  27.75000000  35.00000000  26.50000000
# 2304   8.98500000  ...   8.10300000   9.12900000   8.10300000
# 2305   0.43770000  ...   0.42520000   0.50000000   0.34800000
#
#                  volume         quoteVolume       openTime      closeTime  \
# 0        31524.23250000       1856.16139678  1696487582237  1696573982237
# 1        39971.38300000         93.83246224  1696487575223  1696573975223
# 2        25358.01400000        194.30912816  1696487570677  1696573970677
# 3        10370.08000000          2.66213069  1696487560644  1696573960644
# 4          161.40000000          0.22209310  1696487570186  1696573970186
# ...                 ...                 ...            ...            ...
# 2301      6789.70000000       6869.66680000  1696469327188  1696555727188
# 2302     39156.70000000      33970.05081000  1696487579510  1696573979510
# 2303   1203590.00000000   33309286.09000000  1696487579319  1696573979319
# 2304  17235404.00000000  150549174.51700000  1696487583201  1696573983201
# 2305     51856.80000000      22809.31443000  1696487581782  1696573981782
#
#         firstId     lastId  count
# 0     423617004  423650416  33413
# 1      93710350   93719046   8697
# 2     227553771  227575151  21381
# 3      45549339   45550518   1180
# 4       5403508    5403532     25
# ...         ...        ...    ...
# 2301        345        364     20
# 2302          0        108    109
# 2303          0       3310   3311
# 2304          0      40897  40898
# 2305          0        199    200
#
# [2306 rows x 21 columns]
